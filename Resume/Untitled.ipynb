# %%
# !pip install mysql-connector-python

# %%
import pandas as pd
import numpy as np
import mysql.connector

# %%
conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Nishi@22aug",  # Replace with your actual correct password
    database="new_schema"
)

# Alternative approach if you're not sure about credentials:
# 1. Verify your MySQL username and password
# 2. Make sure the user has permissions for the database
# 3. Check if the database "new_schema" exists
# 4. You might need to create the user or grant permissions:
#    CREATE USER 'root'@'localhost' IDENTIFIED BY 'your_password';
#    GRANT ALL PRIVILEGES ON new_schema.* TO 'root'@'localhost';
#    FLUSH PRIVILEGES;

# %%
conn.is_connected()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 conn.is_connected()
#
# NameError: name 'conn' is not defined

# %%
def connect_to_db():
    return mysql.connector.connect( 
    host="localhost",
    user="root",
    password="Nishi@22aug",  # Replace with your actual correct password
    database="new_schema"
)

# %%
conn_to_db().is_connected()

# %%
db = connect_to_db()
cursor = db.cursor(dictionary = True)

# %%
cursor
